# %% [markdown]
# <a href="https://colab.research.google.com/github/GGeorge777/python.ETE/blob/main/Desafio3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
##
#1. Faça um Programa que leia um vetor de 5 números inteiros e mostre-os.
#2. Faça um Programa que leia um vetor de 10 números reais e mostre-os na ordem inversa.
#3. Faça um Programa que leia 4 notas, mostre as notas e a média na tela.
#4. Faça um Programa que leia um vetor de 10 caracteres, e diga quantas consoantes foram lidas. Imprima as consoantes.
#5. Faça um Programa que leia 20 números inteiros e armazene-os num vetor. Armazene os números pares no vetor PAR e os números IMPARES no vetor impar. Imprima os três vetores.
#6. Faça um Programa que peça as quatro notas de 10 alunos, calcule e armazene num vetor a média de cada aluno, imprima o número de alunos com média maior ou igual a 7.0.
#7. Faça um Programa que leia um vetor de 5 números inteiros, mostre a soma, a multiplicação e os números.
#8. Faça um Programa que peça a idade e a altura de 5 pessoas, armazene cada informação no seu respectivo vetor. Imprima a idade e a altura na ordem inversa a ordem lida.
#9. Faça um Programa que leia um vetor A com 10 números inteiros, calcule e mostre a soma dos quadrados dos elementos do vetor.
#10. Faça um Programa que leia dois vetores com 10 elementos cada. Gere um terceiro vetor de 20 elementos, cujos valores deverão ser compostos pelos elementos intercalados dos dois outros vetores.

#QUESTÃO 1
v1 = [1, 
      2, 
      3, 
      4, 
      5 ] 
print(v1)

#QUESTÃO 2
v= [1.2, 2.5, 3.66, 4.87, 5.54, 6.43, 7.44, 8.12, 9.87, 10.2]
print(v[::-1])

#QUESTÃO 3
notas =  [10, #teste1
          9, #teste2
          8, #teste3
          7 ] #teste4
#FAÇA A MÉDIA
media= sum(notas)/len(notas)
print(media)

#QUESTÃO 4
caracter=[]
vogal=["a","e","i","o","u"]
contvogal = 0
x=1 
while x <= 10:
  entrada = input("Caractere %d: " %x)
  x += 1
  caracter.append(entrada)
  if entrada in vogal:
    contvogal += 1
print ("Consoantes: ",(len(caract))-contvogal)

#QUESTÃO 5

num=[]
impar=[]
par=[]
for num in range(0,20):
       vetor.append(int(input("Digite um numero: ")))
  for num in range(0,20):
      if num[numero] % 2 == 0:
          par.append(vetor[numero])
      else:
          impar.append(vetor[numero])
print("Vetor com 20 elementos: " + str(vetor))
print("Vetor com elementos pares: " + str(par))
print("Vetor com elementos impares: " + str(impar))

#QUESTÃO 6
listaNotas = []
notasAlunos = []
print ('Notas dos alunos')
for i in range(10):
  media = 0
  notasAluno = []
  print ('Aluno: '+ str(1+1))
  for j in range(4):
  notasAluno.append(float(input('Nota: ' + str(j+i) + '\n')))
  media += notasAluno[j]
  print (media)
media = media/4
listaNotas.append(media)

print(listaNotas)

#QUESTÃO 7

vetor = []
cont = 1
for x in range(0, 5):
  vetor.append(int(input(f'Digite o {cont}° número: ')))
  cont = cont + 1
print(f'Soma: {vetor[0]+vetor[1]+vetor[2]+vetor[3]+vetor[4]}')
print(f'Multiplicação: {vetor[0]*vetor[1]*vetor[2]*vetor[3]*vetor[4]}')
print(f'Vetor: {vetor}')

#QUESTÃO 8 

idade = []
altura = []
cont = 1
for x in range(0, 5):
  idade.append(int(input(f'Digite a idade da {cont}° pessoa: ')))
  altura.append(float(input(f'Digite a altura da {cont}° pessoa em CM: ')))
  cont = cont + 1
idade.reverse()
altura.reverse()
print(f'Altura: {altura}')
print(f'Idade: {idade}')

#QUESTÃO 9 

vetor = []
soma = 0
cont = 1
for x in range(0, 10):
  vetor.append(int(input(f'Digite o {cont}° número: ')))
  soma = soma + (vetor[len(vetor)-1]**2)
  cont = cont + 1
print(f'A soma dos quadrados dos elementos do vetor é: {str(soma)}')

#QUESTÃO 10 

vetor1 = []
vetor2 = []
vetor3 = []
cont = 1
for elemento in range(0, 10):
  vetor1.append(int(input(f'Digite o {cont}° elemento da primeira lista: ')))
  cont = cont + 1
cont = 1
for elemento in range(0, 10):
  vetor2.append(int(input(f'Digite o {cont}° elemento da segunda lista: ')))
  cont = cont + 1
for elemento in range(0, 10):
  vetor3.append(vetor1[elemento])
  vetor3.append(vetor2[elemento])
print(vetor3)
